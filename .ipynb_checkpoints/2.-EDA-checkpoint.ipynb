# %% [markdown]
# # Descriptive Statistics Review
#
# In this second part of the lab, we are going to continue working with the data that we cleaned in the last part.
# Be sure to continue to write clean code and comment your work well!
#
# First, lets import our libraries and the data we saved.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
diamonds = pd.read_csv('diamonds_clean.csv')
diamonds = diamonds.drop('Unnamed: 0', axis=1)

# %% [markdown]
# Now that we cleaned our data, we can proceed with some exploratory analysis. We will analyze the features that affect price the most.
#
# Let's start by looking at how the charateristics of a diamond (especially the price, since that's our focus) change based on its color. Remember that you can use the `groupby()` method in pandas.
#
# **Using the `describe()` method, take a look on the dataset paying special attention to the variability. Comment what you see.**

# %%
#your code here
diamonds.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53931.000000  53931.000000  53931.000000  53931.000000  53931.000000
# mean       0.797857     61.749389     57.457038   3931.982589      5.731964
# std        0.473962      1.432475      2.234084   3988.612539      1.119634
# min        0.200000     43.000000     43.000000    326.000000      3.730000
# 25%        0.400000     61.000000     56.000000    949.500000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.000000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z  clarity_rating  color_rating
# count  53931.000000  53931.000000    53931.000000  53931.000000
# mean       5.733890      3.539800        3.051139      2.594185
# std        1.111753      0.691559        1.647101      1.701170
# min        3.680000      2.060000        0.000000      0.000000
# 25%        4.720000      2.910000        2.000000      1.000000
# 50%        5.710000      3.530000        3.000000      3.000000
# 75%        6.540000      4.040000        4.000000      4.000000
# max       11.420000      6.970000        7.000000      6.000000

# %%
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#    clarity_rating  color_rating
# 0               1             1
# 1               2             1
# 2               4             1
# 3               3             5
# 4               1             6

# %%
#your comments here
'''
There is pretty big range of prices, 18,497 USD. Average price is closer to minimum rather than to maximum and the same comment
is applicable for 75%tile, it means there are much more cheaper stones in the population than very expensive ones.
St.deviation of table and depth is not that high, which in comparison with st.deviation of price means that variability of
price doesn't directly relate to variability of size. Same comment can be made regarding carat.
On the other hand, st.deviation of clarity is rather high and st.deviation of color is even higher which means that covariance
coefficient for clarity and a price and color and a price should be positive and high.

The heaviest stone is 5 carat which is equal to 1 gram and looks huge (in a ring, for instance).
'''

# %% [markdown]
# Let's proceed to check each feature separately.
#
# **Before starting, which features do you think that will affect the price most and why? You will contrast your hypotheses with your results.**

# %%
#your hypotheses here
'''
As per analysis above we can assume that color quality has the greatest impact on the price.
But analysis above doesn't take into account cut as it's not numeric field but I think this is actually the most important
characteristic of diamonds so I expect cut to have the greatest impact on the price.
P.S. Few years ago I read an interview regarding very affordable Russian jewellery chain and one of the main reasons they
have such low prices was small amount of faces of diamonds they sell. That's how I came with the hypothesis above.
'''

# %% [markdown]
# ## 1. The `color` column
# First, let's look at the color column.
#
# **For each different color, find the mean of each column. You should have a matrix with every color as rows and the columns `carat`, `clarity`, etc as columns.**

# %%
#your code here
diamonds.groupby('color').mean()
# Out:
#           carat      depth      table        price         x         y  \
# color
# D      0.657715  61.698066  57.404355  3168.106436  5.417851  5.421928
# E      0.657867  61.662090  57.491201  3076.752475  5.411580  5.416949
# F      0.736509  61.694087  57.433148  3725.091938  5.616727  5.620529
# G      0.771088  61.757449  57.288060  3998.145173  5.678549  5.681198
# H      0.911496  61.836911  57.518239  4484.028189  5.984522  5.979882
# I      1.026927  61.846385  57.577278  5091.874954  6.222826  6.222728
# J      1.162137  61.887215  57.812393  5323.818020  6.519338  6.518109
#
#               z  clarity_rating  color_rating
# color
# D      3.343320        2.691025           0.0
# E      3.337767        2.969889           1.0
# F      3.466248        3.134605           2.0
# G      3.507878        3.463419           3.0
# H      3.698984        2.934104           4.0
# I      3.846940        2.964035           5.0
# J      4.033244        2.776353           6.0

# %% [markdown]
# **What do you see? Pay special attention to the relationship between price and color.**

# %%
#your thoughts here
'''
There is positive correlation between color rating and a price (except first two colors), same applies to all other measurements
except 'table' where the stone of a good color quality (G) has the smallest table.
'''

# %% [markdown]
# Let's go further into the color feature. We will plot the frequency distribution of the diamonds color in our dataset.
#
# **Plot the distribution and analyze it. Remember that you can use the pandas `plot()` method.**

# %%
#your code here
diamonds['color_rating'].plot.hist()

# %%
#your comments here
'''
The most common color category is G which has rating 3 out of 6, so basically average stones are the most common.
'''

# %% [markdown]
# ## 2.The `carat` column

# %% [markdown]
# Let's check the `carat` (weight), since this could also be a potential factor for price change.
#
# **Find the mean of each column for each value of `carat` using the `groupby` method. Then comment your results.**

# %%
#your code here
diamonds.groupby('carat').mean()
# Out:
#            depth      table         price          x          y         z  \
# carat
# 0.20   61.100000  59.333333    365.166667   3.786667   3.753333  2.303333
# 0.21   60.511111  58.444444    380.222222   3.874444   3.837778  2.332222
# 0.22   61.620000  60.400000    391.400000   3.898000   3.848000  2.386000
# 0.23   61.426621  58.034130    486.143345   3.946382   3.973379  2.431468
# 0.24   61.599213  57.488189    505.185039   3.990157   4.019331  2.465591
# ...          ...        ...           ...        ...        ...       ...
# 4.00   63.300000  58.000000  15984.000000  10.010000   9.940000  6.310000
# 4.01   61.750000  61.500000  15223.000000  10.080000  10.015000  6.205000
# 4.13   64.800000  61.000000  17329.000000  10.000000   9.850000  6.430000
# 4.50   65.800000  58.000000  18531.000000  10.230000  10.170000  6.710000
# 5.01   65.500000  59.000000  18018.000000  10.740000  10.540000  6.970000
#
#        clarity_rating  color_rating
# carat
# 0.20         2.833333      0.833333
# 0.21         2.666667      0.555556
# 0.22         2.600000      1.200000
# 0.23         4.901024      1.481229
# 0.24         4.972441      1.814961
# ...               ...           ...
# 4.00         0.000000      5.000000
# 4.01         0.000000      5.500000
# 4.13         0.000000      4.000000
# 4.50         0.000000      6.000000
# 5.01         0.000000      6.000000
#
# [273 rows x 8 columns]

# %%
#your comments
'''
There are 273 different values of carat in population so table above can't be easily processed with a naked eye.
There seems to be positibe correlation between carat and price as well as carat and color. On the other hand it seems to be
no correlation between carat and all other measures.
There is also an interesting pattern between carat and clarity, it looks like the heaviest stones have the worst clarity rating.
'''

# %% [markdown]
# **Plot a histogram of the `carat` column by using the `plot` method (see the docs to find an easy way to do so). What is happening?**

# %%
#your code here
diamonds['carat'].plot.hist()

# The most common stones are below 0.5 carat; there are almost no stones above 2 carat in the population.

# %% [markdown]
# # 3. The `table` and `clarity` column
# Finally, let's check the `table`.
#
# **Find the mean of each column for each value of `table` using the `groupby` method. Then comment your results.**

# %%
#your code here
diamonds.groupby('table').mean()
# Out:
#         carat  depth    price      x      y      z  clarity_rating  \
# table
# 43.0   1.0400  62.90   4997.0  6.450  6.410  4.040            4.00
# 44.0   0.2900  62.80    474.0  4.200  4.240  2.650            4.00
# 49.0   0.6500  64.25   2290.5  5.355  5.320  3.425            3.00
# 50.0   1.5100  61.50   8995.5  7.380  7.295  4.510            2.00
# 50.1   0.9400  66.00   3353.0  6.130  6.170  4.060            1.00
# ...       ...    ...      ...    ...    ...    ...             ...
# 71.0   0.6800  58.00   1633.0  5.850  5.700  3.350            2.00
# 73.0   0.6025  68.90   2406.5  5.520  5.465  3.745            3.25
# 76.0   0.7900  65.30   2362.0  5.520  5.130  3.350            2.00
# 79.0   0.8100  68.80   2301.0  5.260  5.200  3.580            1.00
# 95.0   2.0100  58.60  13387.0  8.320  8.310  4.870            2.00
#
#        color_rating
# table
# 43.0            5.0
# 44.0            1.0
# 49.0            3.0
# 50.0            3.0
# 50.1            4.0
# ...             ...
# 71.0            3.0
# 73.0            1.5
# 76.0            3.0
# 79.0            2.0
# 95.0            2.0
#
# [127 rows x 8 columns]

# %%
#your comments here
'''
This table is again bigger than can fit on the screen so it's not easy to process it without using other analytical
measurements but it seems there is no correlation between table ans any other measure.
'''

# %% [markdown]
# **Finally, do the same with the `clarity` column.**

# %%
#your code here
diamonds.groupby('clarity').mean().sort_values(by=['clarity_rating'])
# Out:
#             carat      depth      table        price         x         y  \
# clarity
# I1       1.283846  62.734278  58.303779  3924.168691  6.761093  6.709379
# SI2      1.077501  61.771879  57.926923  5061.489498  6.403973  6.394177
# SI1      0.850482  61.853042  57.662541  3996.001148  5.888383  5.888256
# VS2      0.763850  61.724249  57.418040  3924.166204  5.658633  5.659782
# VS1      0.727108  61.667968  57.313966  3839.144308  5.572860  5.580017
# VVS2     0.596202  61.663778  57.024990  3283.737071  5.218454  5.232118
# VVS1     0.503131  61.624521  56.883881  2519.512315  4.961721  4.976437
# IF       0.505123  61.510615  56.507207  2864.839106  4.968402  4.989827
#
#                 z  clarity_rating  color_rating
# clarity
# I1       4.224683             0.0      3.031039
# SI2      3.952086             1.0      2.529873
# SI1      3.641099             2.0      2.551550
# VS2      3.492788             3.0      2.505630
# VS1      3.438291             4.0      2.838188
# VVS2     3.221465             5.0      2.430517
# VVS1     3.062132             6.0      2.649152
# IF       3.061659             7.0      2.898324

# %%
#your comments here
'''
There is negative correlation between clarity and all other measures, except for price. With price it seems there is no
correlation at all.
'''

# %% [markdown]
# **After looking at your results, which features do you think will affect price the most now? Regarding your hypotheses, do they match your final results? Provide a small overview.**

# %%
# We haven't checked cut yet and as it's mine main hypothesis I will check it now.
cut_rating = {'Fair': 0, 'Good': 1, 'Very Good': 2, 'Premium': 3, 'Ideal': 4}
diamonds['cut_rating'] = [cut_rating[i] for i in diamonds['cut'] if i in cut_rating.keys()]
diamonds.head(10)
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z  \
# 0   0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7   0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8   0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9   0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39
#
#    clarity_rating  color_rating  cut_rating
# 0               1             1           4
# 1               2             1           3
# 2               4             1           1
# 3               3             5           3
# 4               1             6           1
# 5               5             6           2
# 6               6             5           2
# 7               2             4           2
# 8               3             1           0
# 9               4             4           2

# %%
diamonds.groupby('cut').mean().sort_values(by=['cut_rating'])
# Out:
#               carat      depth      table        price         x         y  \
# cut
# Fair       1.046078  64.045743  59.048850  4357.500932  6.250777  6.186501
# Good       0.849241  62.365171  58.694107  3929.598083  5.841166  5.853130
# Very Good  0.806365  61.818152  57.956560  3981.664101  5.741171  5.770503
# Premium    0.891754  61.264672  58.746185  4581.923992  5.974600  5.941899
# Ideal      0.702780  61.709383  55.951756  3457.038981  5.507962  5.519339
#
#                   z  clarity_rating  color_rating  cut_rating
# cut
# Fair       3.984612        2.020510      2.851461         0.0
# Good       3.643071        2.603589      2.573409         1.0
# Very Good  3.557726        2.999338      2.566427         2.0
# Premium    3.650238        2.739629      2.697346         3.0
# Ideal      3.402373        3.458304      2.529259         4.0

# %%
#your thoughts here
'''
There is no correlation between quality of cut and price, as well as with all other measures except clarity.

Based on observations above we can assume that carat has the greatest impact on price of a diamond.
'''

# %% [markdown]
# # Bonus: taking a deeper look with plots and correlations
#
# To take deeper look, we will use the `pairplot` method of `seaborn` library. This method plots a scatterplot for each pair of features and in the diagonal the distribution of the feature.
#
# So if you have many features it will take a while, be careful!

# %%
#Run this code
import seaborn as sns
sns.pairplot(diamonds, diag_kind = 'kde', plot_kws = {'alpha': 0.6, 's': 80, 'edgecolor': 'k'})

# %% [markdown]
# **What do you see here? What relationships between variables are the most interesting?**

# %%
#your thoughts here
'''
There is very strong positive correlation between carat and size measures of the stone, which totally makes sense.
There is strong positive correlation between size measures and a price, also this curve is very steep, so at some point
size of the stone doesn't have big impact on the price anymore, stones of the same size can vary a lot in price.
Slope of the curve showing correlation between carat and price is even steeper. So at some point other factors starts playing
bigger role than size and weight but it's not clear from the graphs what these factors are. Maybe, some of them are not
included into data set.
'''

# %% [markdown]
# Now we will see a correlation matrix with a plot. As you know a higher correlation means that the feature could be an effect (**but is not for sure**) for the changes on the price.
#
# We will see this with a matrix with colors. A lighter color means greater correlation.
#
# This is done with the `seaborn` library as well.

# %%
#Run this code
plt.figure(figsize=(20, 20))
p = sns.heatmap(diamonds.corr(), annot=True, square=True)

# %% [markdown]
# **What do you see here? Regarding the results before, does it fit with them?**

# %%
#your thoughts here
'''
Heatmap confirms my conclusion made based on pairplot observation, the strongest correlation is between price and carat.
Price has very weak (and even negative!) correlation with cut quality, which complitely disprove my hypothesis.
I found another article which says that cut is one of the most important characteristics of the gem (any gem, not only diamonds),
but our data doesn't agree with this fact.
'''

# %% [markdown]
# Finally, we will calculate the linear regression between the price and the weight. This will be done first by plotting it with the `seaborn` library and then calculating the error with the `scipy` library.

# %%
#Run this code
plt.figure(figsize=(10, 10))
sns.regplot(diamonds.carat, diamonds.price, scatter=True)

# %%
#Run this code
from scipy import stats
slope, intercept, r_value, p_value, std_err = stats.linregress(diamonds.carat, diamonds.price)
r2 = r_value ** 2
r2
# Out:
# 0.8493551426050261

# %% [markdown]
# **What do you think?**

# %%
#your thoughts here
'''
As mentioned before starting at around 1 carat stones can cost the same amount or money as twice or even three times heavier
diamonds. There should be some factors which give such effect but we can't definitely name them yet.
Interesting thing - diamond with 5 carat is not the most expensive.
'''

# %% [markdown]
# **Would you do any other checks on other features? Do you have any comments regarding `carat`?**

# %%
#your thoughts here

# %% [markdown]
# **Conlcusion**

# %% [markdown]
# **From our dataset** we can conclude that although `color` and `clarity` have a classification, and thus an assigned importance or weight, they do not influence the monetary value of a diamond in determining way. While it is true that different colors or clarities may have different prices, upon closer examination those variations in price seem to be linked to `carat` (weight) and its `dimensions`. In our analysis, the key factor to determining a diamond's value was placed solely in the aforementioned features, since we can see in our correlation coefficients and in the coefficient of determination that these features are closely related.
